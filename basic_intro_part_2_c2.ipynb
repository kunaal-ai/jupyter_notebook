# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = [1, 2, 3, 4, 5, 6]
y = [10, 19, 11, 16, 22, 15]

# %%
plt.plot(x, y, color='red', linewidth=3, linestyle='--')
# '-' | '--' | '-.' | ':' |
